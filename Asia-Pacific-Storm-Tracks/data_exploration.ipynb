# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.pyplot import subplots

# %%
df = pd.read_csv('AsiaPacificStormtracks2004-to-2018.csv')

# %%
df.head()
# Out:
#   REGION  STORM_NO   NAME  ADVISORY   ADV_DATE  ADV_HOUR  SPEED  PRESSURE  \
# 0      W         0  (09W)         0  8/11/2007        21     40         0
# 1      W         0  (09W)         0  8/11/2007        15     40         0
# 2      W         0  (09W)         0  8/11/2007         9     30         0
# 3      W         0  (10W)         0  8/28/2007         3     35         0
# 4      W         0  (10W)         0  8/27/2007        21     25         0
#
#   TYPE   LAT        LONG
# 0    S  17.0  134.899994
# 1    S  17.4  135.100006
# 2    D  17.4  135.500000
# 3    D  21.6  156.100006
# 4    D  20.4  155.399994

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Read the CSV file into a DataFrame
df = pd.read_csv('AsiaPacificStormtracks2004-to-2018.csv')

# Display summary statistics
summary_stats = df.describe()

# Plot histograms for numeric columns
numeric_cols = ['STORM_NO', 'ADV_DATE', 'ADV_HOUR', 'SPEED', 'PRESSURE', 'LAT', 'LONG']
df[numeric_cols].hist(bins=20, figsize=(15, 10))
plt.suptitle('Histograms of Numeric Columns')
plt.show()

# Plot box plots for numeric columns
plt.figure(figsize=(15, 10))
sns.boxplot(data=df[numeric_cols])
plt.title('Box Plots of Numeric Columns')
plt.show()

# Plot a scatter plot for latitude and longitude
plt.figure(figsize=(10, 8))
sns.scatterplot(x='LONG', y='LAT', data=df, hue='TYPE', palette='viridis', alpha=0.7)
plt.title('Scatter Plot of Latitude vs. Longitude')
plt.show()

# Display summary statistics
print("Summary Statistics:")
print(summary_stats)
# Out:
# Summary Statistics:
#            STORM_NO      ADVISORY      ADV_HOUR         SPEED      PRESSURE  \
# count  20631.000000  20631.000000  20631.000000  20631.000000  20631.000000
# mean      11.935776      1.335563     71.171005     58.141147    322.785711
# std       59.137407      5.507893    286.232189     29.997344    463.679977
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.000000      0.000000      6.000000     35.000000      0.000000
# 50%        0.000000      0.000000     12.000000     50.000000      0.000000
# 75%        4.000000      0.000000     18.000000     75.000000    977.000000
# max      606.000000     75.000000   1800.000000    170.000000   1019.000000
#
#                 LAT          LONG
# count  20631.000000  20631.000000
# mean      20.605358     15.472488
# std       32.439746     94.865756
# min     -179.600000   -179.900000
# 25%        0.000000    -67.649998
# 50%       16.900000      0.000000
# ...
