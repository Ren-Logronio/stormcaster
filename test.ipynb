# %%
import geopandas as gpd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 import geopandas as gpd
#
# ModuleNotFoundError: No module named 'geopandas'

# %%
pip install geopandas
# Out:
# Requirement already satisfied: geopandas in c:\users\carre\appdata\local\programs\python\python312\lib\site-packages (0.14.1)
# Requirement already satisfied: fiona>=1.8.21 in c:\users\carre\appdata\local\programs\python\python312\lib\site-packages (from geopandas) (1.9.5)
# Requirement already satisfied: packaging in c:\users\carre\appdata\local\programs\python\python312\lib\site-packages (from geopandas) (23.2)
# Requirement already satisfied: pandas>=1.4.0 in c:\users\carre\appdata\local\programs\python\python312\lib\site-packages (from geopandas) (2.1.3)
# Requirement already satisfied: pyproj>=3.3.0 in c:\users\carre\appdata\local\programs\python\python312\lib\site-packages (from geopandas) (3.6.1)
# Requirement already satisfied: shapely>=1.8.0 in c:\users\carre\appdata\local\programs\python\python312\lib\site-packages (from geopandas) (2.0.2)
# Requirement already satisfied: attrs>=19.2.0 in c:\users\carre\appdata\local\programs\python\python312\lib\site-packages (from fiona>=1.8.21->geopandas) (23.1.0)
# Requirement already satisfied: certifi in c:\users\carre\appdata\local\programs\python\python312\lib\site-packages (from fiona>=1.8.21->geopandas) (2023.11.17)
# Requirement already satisfied: click~=8.0 in c:\users\carre\appdata\local\programs\python\python312\lib\site-packages (from fiona>=1.8.21->geopandas) (8.1.7)
# Requirement already satisfied: click-plugins>=1.0 in c:\users\carre\appdata\local\programs\python\python312\lib\site-packages (from fiona>=1.8.21->geopandas) (1.1.1)
# Requirement already satisfied: cligj>=0.5 in c:\users\carre\appdata\local\programs\python\python312\lib\site-packages (from fiona>=1.8.21->geopandas) (0.7.2)
# Requirement already satisfied: six in c:\users\carre\appdata\local\programs\python\python312\lib\site-packages (from fiona>=1.8.21->geopandas) (1.16.0)
# Requirement already satisfied: setuptools in c:\users\carre\appdata\local\programs\python\python312\lib\site-packages (from fiona>=1.8.21->geopandas) (68.2.2)
# Requirement already satisfied: numpy<2,>=1.26.0 in c:\users\carre\appdata\local\programs\python\python312\lib\site-packages (from pandas>=1.4.0->geopandas) (1.26.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\carre\appdata\local\programs\python\python312\lib\site-packages (from pandas>=1.4.0->geopandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\carre\appdata\local\programs\python\python312\lib\site-packages (from pandas>=1.4.0->geopandas) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\carre\appdata\local\programs\python\python312\lib\site-packages (from pandas>=1.4.0->geopandas) (2023.3)
# Requirement already satisfied: colorama in c:\users\carre\appdata\local\programs\python\python312\lib\site-packages (from click~=8.0->fiona>=1.8.21->geopandas) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.

# %%
import geopandas as gpd

# %%
shapefile = gpd.read_file("Datasets/UNISYS_tracks_1956_2018Dec31.shp")

# %%
shapefile
# Out:
#        REGION  STORM_NO        NAME  ADVISORY    ADV_DATE  ADV_HOUR  SPEED  \
# 0           S         0  1997-12-02         0  1997-12-03        18     25
# 1           I         0  1979-02-11         0  1979-02-11        12   -999
# 2           A         6        FIFI         0  1958-09-06         6     65
# 3           A         6     FRANCES         0  2004-09-02         0    120
# 4           A         3     UNNAMED         0  1948-09-03         0     40
# ...       ...       ...         ...       ...         ...       ...    ...
# 227569      W         0  THIRTYFIVE         0  2018-12-25       600     25
# 227570      W         0  THIRTYFIVE         0  2018-12-25         0     25
# 227571      W         0  THIRTYFIVE         0  2018-12-24      1800     25
# 227572      W         0   THIRTYSIX         0  2018-12-31      1800     30
# 227573      W         0   THIRTYSIX         0  2018-12-31      1200     30
#
#         PRESSURE TYPE    LAT  LONG_  \
# 0              0    D   -8.6    0.0
# 1              0    D  -16.4    0.0
# 2              0    S   15.6  -55.7
# 3            939    H   22.2  -71.4
# 4              0    S   53.8  -50.0
# ...          ...  ...    ...    ...
# 227569         0    D  135.2    8.2
# 227570         0    D  135.7    7.5
# 227571         0    D  135.8    7.2
# 227572         0    D  111.0    6.6
# 227573         0    D  111.2    7.7
#
#                                                  geometry
# 0       LINESTRING (-18579223.014 -965763.976, -186014...
# 1       LINESTRING (5833141.348 -1792951.710, 5944460....
# 2       LINESTRING (-6022384.445 1620951.321, -6200495...
# 3       LINESTRING (-7836892.155 2471668.297, -7948211...
# 4       LINESTRING (-5721821.827 6912030.437, -5565974...
# ...                                                   ...
# 227569  LINESTRING (15050395.155 909861.812, 15050975....
# 227570  LINESTRING (15106054.901 831717.356, 15106373....
# 227571  LINESTRING (15117186.850 798266.539, 15116491....
# 227572  LINESTRING (12356463.478 731431.181, 12356642....
# 227573  LINESTRING (12378727.376 854030.824, 12379601....
#
# [227574 rows x 12 columns]

# %%
import matplotlib.pyplot as plt

# %%
fig,ax = plt.subplots(figsize=(10,10))
shapefile.plot(ax=ax, column = "REGION")
ax.axis("off")
# Out:
# (-22041257.77392, 22041257.773919996, -6889748.608895002, 12124366.114995)
